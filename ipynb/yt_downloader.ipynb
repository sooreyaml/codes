# %%
# !pip3 install ffmpeg yt_dlp
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import yt_dlp
import os
from pathlib import Path

# %%
# !pip install -U yt-dlp
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.7 MB/s  0:00:00 eta 0:00:01
# ...
#   Attempting uninstall: yt-dlp
#     Found existing installation: yt-dlp 2025.12.8
#     Uninstalling yt-dlp-2025.12.8:
#       Successfully uninstalled yt-dlp-2025.12.8
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# function to download video.
# def download_video(url):
#     ydl_opts = {}
#     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#         ydl.download([url])

def download_video(url, output_path='/Users/sooreoluwa/downloads'):
    Path(output_path).mkdir(parents=True, exist_ok=True)
    
    ydl_opts = {
        'outtmpl': f'{output_path}/%(title)s.%(ext)s',
        'progress_hooks': [lambda d: print(f'Downloading: {d["_percent_str"]}')],
    }
    
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl: # type: ignore
            ydl.download([url])
        print("Video download completed successfully!")
    except Exception as e:
        print(f"Error downloading video: {str(e)}")

# %%
def download_audio(url, output_path='/Users/sooreoluwa/downloads'):
    Path(output_path).mkdir(parents=True, exist_ok=True)
    
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': f'{output_path}/%(title)s.%(ext)s',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        'progress_hooks': [lambda d: print(f'Downloading: {d["_percent_str"]}')],
    }
    
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl: # type: ignore
            ydl.download([url])
        print("Audio download completed successfully!")
    except Exception as e:
        print(f"Error downloading audio: {str(e)}")

# %%
# url = "https://www.youtube.com/watch?v=LxU5_qnVnaw"
# url = "https://www.youtube.com/watch?v=nq2TioeaFE4"
# url = "https://www.youtube.com/watch?v=YuLOmYtlQhQ"
# url = "https://www.youtube.com/watch?v=E90skLYPvY4"
# url = "https://www.youtube.com/watch?v=ZTWFD9RuTA0"
# url = "https://www.youtube.com/watch?v=d70orPgsG7k"
# url = "https://www.youtube.com/watch?v=N0yKAcM5XU0"
# url = "https://www.youtube.com/watch?v=NyGVffrFbo4"
# url = "https://www.youtube.com/watch?v=N6aUL8M-w50"
# url = "https://www.youtube.com/watch?v=EieiNaipT04"     
# url = "https://youtu.be/nTwiliMpTAA?si=N1gf1J4wmsFqvr5F"
# url = "https://youtu.be/-yWdxP2J9dg?si=NgpzXXwTC5tXZPQh"
# url = "https://youtu.be/nED176dRCnA?si=Y1_WFw-1HtyVCDpU"
# url = "https://youtu.be/4KJmKZCMZ3U?si=hgPLV9GcZZ7XLfog"
# url = "https://youtu.be/B3JMh4n0LFQ"
# url = "https://youtu.be/gl485qlFuK0"
url ="https://youtu.be/j0lD7VXeZ8o"
download_audio(url)
# Out:
# [youtube] Extracting URL: https://youtu.be/j0lD7VXeZ8o
# [youtube] j0lD7VXeZ8o: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] j0lD7VXeZ8o: Downloading android sdkless player API JSON
# [youtube] j0lD7VXeZ8o: Downloading web safari player API JSON
# WARNING: [youtube] j0lD7VXeZ8o: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] j0lD7VXeZ8o: Downloading m3u8 information
# ...
